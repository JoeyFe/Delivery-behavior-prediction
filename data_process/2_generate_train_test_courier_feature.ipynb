# %%
import pandas as pd
import numpy as np
import time
import datetime
import pickle
import random
import os
import logging
LOG_FORMAT = "%(asctime)s - %(levelname)s - %(message)s"
# logging.basicConfig(level=logging.INFO, filename='log_Model', format=LOG_FORMAT)
logging.basicConfig(level=logging.INFO, format=LOG_FORMAT)

from IPython.display import display, HTML
def show_df(df):
    display(HTML(df.to_html()))

# %% [markdown]
# # 加载数据

# %%
logging.info('start read data')

pickle_path = './0_data_sort_out/train_dataset_mp.pickle'
with open(pickle_path, 'rb') as f:
    train_dataset_mp = pickle.load(f)
key_list_train, mp_action_train, mp_distance_train, mp_order_train, mp_distance_train_detail = \
train_dataset_mp['key_list'], train_dataset_mp['mp_action'], train_dataset_mp['mp_distance'], train_dataset_mp['mp_order'], train_dataset_mp['mp_distance_detail']

pickle_path = './0_data_sort_out/testA_dataset_mp.pickle'
with open(pickle_path, 'rb') as f:
    testA_dataset_mp = pickle.load(f)
key_list_testA, mp_action_testA, mp_distance_testA, mp_order_testA, mp_distance_testA_detail = \
testA_dataset_mp['key_list'], testA_dataset_mp['mp_action'], testA_dataset_mp['mp_distance'], testA_dataset_mp['mp_order'], testA_dataset_mp['mp_distance_detail']

pickle_path = './0_data_sort_out/train_dataset_df.pickle'
with open(pickle_path, 'rb') as f:
    train_dataset_df = pickle.load(f)
df_actions_train, df_couriers_train, df_distances_train, df_orders_train = \
train_dataset_df['df_actions'], train_dataset_df['df_couriers'], train_dataset_df['df_distances'], train_dataset_df['df_orders']
    
pickle_path = './0_data_sort_out/testA_dataset_df.pickle'
with open(pickle_path, 'rb') as f:
    testA_dataset_df = pickle.load(f)
df_actions_testA, df_couriers_testA, df_distances_testA, df_orders_testA = \
testA_dataset_df['df_actions'], testA_dataset_df['df_couriers'], testA_dataset_df['df_distances'], testA_dataset_df['df_orders']

logging.info('finish read data')
# Out:
# 2021-01-19 16:27:00,936 - INFO - start read data
# 2021-01-19 16:27:23,986 - INFO - finish read data

# %%
pickle_path = './1_build_dataset/df_train_info.pickle'
with open(pickle_path, 'rb') as f:
    df_train_info = pickle.load(f)

pickle_path = './1_build_dataset/df_testA_info.pickle'
with open(pickle_path, 'rb') as f:
    df_testA_info = pickle.load(f)

# %%
delay_feature_list = []
logging.info('start delay feature build')

for i, (date, courier, wave_idx) in enumerate(key_list_train):
    if (i + 1) % 10000 == 0:
        logging.info('build %d train sample' % i)
    
    df_a_action = mp_action_train[date][courier][wave_idx]
    df_a_order = mp_order_train[date][courier][wave_idx]
    know_len = df_train_info.iloc[i].know_lens
    cnt_pickup_delay, cnt_deliver_delay = 0, 0
    delay_feature_dict = {}
    
    for j in range(know_len):
        action_row = df_a_action.iloc[j]
        tracking_id = action_row.tracking_id
        cur_time = action_row.expect_time
        df_order_info = df_a_order.query('tracking_id == @tracking_id')
        
        estimate_pick_time = df_order_info.estimate_pick_time
        promise_deliver_time = df_order_info.promise_deliver_time
        delay_feature_dict['courier_id'] = courier

        if action_row.action_type == 'PICKUP':
            delay_feature_dict['delay_type'] = 'PICKUP'
            delay_feature_dict['delay'] = (cur_time > estimate_pick_time).iloc[0]
            delay_feature_dict['delay_time'] = (cur_time - estimate_pick_time).iloc[0]
        elif action_row.action_type == 'DELIVERY':
            delay_feature_dict['delay_type'] = 'DELIVERY'
            delay_feature_dict['delay'] = (cur_time > promise_deliver_time).iloc[0]
            delay_feature_dict['delay_time'] = (cur_time - promise_deliver_time).iloc[0]
        delay_feature_list.append(delay_feature_dict)

for i, (date, courier, wave_idx) in enumerate(key_list_testA):
    if (i + 1) % 1000 == 0:
        logging.info('build %d testA sample' % i)
        
    df_a_action = mp_action_testA[date][courier][wave_idx]
    df_a_order = mp_order_testA[date][courier][wave_idx]
    know_len = df_testA_info.iloc[i].know_lens
    cnt_pickup_delay, cnt_deliver_delay = 0, 0
    delay_feature_dict = {}
    
    for j in range(know_len):
        action_row = df_a_action.iloc[j]
        tracking_id = action_row.tracking_id
        cur_time = action_row.expect_time
        df_order_info = df_a_order.query('tracking_id == @tracking_id')
        
        estimate_pick_time = df_order_info.estimate_pick_time
        promise_deliver_time = df_order_info.promise_deliver_time
        delay_feature_dict['courier_id'] = courier
        
        if action_row.action_type == 'PICKUP':
            delay_feature_dict['delay_type'] = 'PICKUP'
            delay_feature_dict['delay'] = (cur_time > estimate_pick_time).iloc[0]
            delay_feature_dict['delay_time'] = (cur_time - estimate_pick_time).iloc[0]
        elif action_row.action_type == 'DELIVERY':
            delay_feature_dict['delay_type'] = 'DELIVERY'
            delay_feature_dict['delay'] = (cur_time > promise_deliver_time).iloc[0]
            delay_feature_dict['delay_time'] = (cur_time - promise_deliver_time).iloc[0]
        
        delay_feature_list.append(delay_feature_dict)

logging.info('finish delay feature build')


def apply_delay(df):
    df_delivery = df.query('delay_type == "DELIVERY"')
    df_pickup = df.query('delay_type == "PICKUP"')
    feature_dict = {'delivery_num' : df_delivery.shape[0], 'pickup_num' : df_pickup.shape[0]}
    feature_dict['delivery_delay_count'] = sum(df_delivery['delay'])
    feature_dict['pickup_delay_count'] = sum(df_pickup['delay'])
    
    if feature_dict['pickup_num'] == 0:
        feature_dict['pickup_delay_time_avg'] = 0
        feature_dict['pickup_delay_rate'] = 0
    else:
        feature_dict['pickup_delay_time_avg'] = df_pickup['delay_time'].apply(lambda x : x if x > 0 else 0).mean()
        feature_dict['pickup_delay_rate'] = feature_dict['pickup_delay_count'] / feature_dict['pickup_num']
    
    if feature_dict['delivery_num'] == 0:
        feature_dict['delivery_delay_time_avg'] = 0
        feature_dict['delivery_delay_rate'] = 0
    else:
        feature_dict['delivery_delay_time_avg'] = df_delivery['delay_time'].apply(lambda x : x if x > 0 else 0).mean()
        feature_dict['delivery_delay_rate'] = feature_dict['delivery_delay_count'] / feature_dict['delivery_num']


    return pd.Series(feature_dict)
#增加骑手的延误特征

df_delay_info = pd.DataFrame(delay_feature_list)
df_courier_delay_info = df_delay_info.groupby('courier_id').apply(apply_delay)

courier_delay_features = ['pickup_delay_rate', 'delivery_delay_rate', 'pickup_delay_time_avg', 'delivery_delay_time_avg',
                         'delivery_delay_count', 'pickup_delay_count']

for delay_feature in courier_delay_features:
    df_couriers_train[delay_feature] = df_couriers_train['courier_id'].map(df_courier_delay_info[delay_feature])
    df_couriers_testA[delay_feature] = df_couriers_testA['courier_id'].map(df_courier_delay_info[delay_feature])  
df_couriers_train.head()

#映射为字典[courier_id][date]
def build_couriers_features(df_couriers, key_list):
    
    df_index_couriers = df_couriers.groupby('courier_id').apply(lambda x : x.groupby('date').apply(lambda x:x) )
    couriers_set = set(df_couriers['courier_id'])
    mp_couriers_features = {}
    for courier in couriers_set:
        df_a_couriers = df_index_couriers.loc[courier]
        mp_couriers_features[courier] = {}
        for idx in df_a_couriers.index:
            date = df_a_couriers.at[idx, 'date']
            mp_couriers_features[courier][date] = df_a_couriers.loc[idx]
    return mp_couriers_features

logging.info('start building couriers features')
mp_couriers_features_train = build_couriers_features(df_couriers_train, key_list_train)
mp_couriers_features_testA = build_couriers_features(df_couriers_testA, key_list_testA)


logging.info('finish building couriers features')
# Out:
# 2021-01-19 16:27:24,040 - INFO - start delay feature build
# 2021-01-19 16:28:05,592 - INFO - finish delay feature build
# 2021-01-19 16:28:09,307 - INFO - start building couriers features
# 2021-01-19 16:28:16,256 - INFO - finish building couriers features

# %%
mp_couriers_features_train
# Out:
# {100681730: {Timestamp('2020-02-01 00:00:00'): courier_id                           100681730
#   level                                        2
#   speed                                  4.48985
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  452.571
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          21
#   Name: 631, dtype: object},
#  122220553: {Timestamp('2020-02-01 00:00:00'): courier_id                           122220553
#   level                                        3
#   speed                                  4.64289
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.346154
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  232.846
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 539, dtype: object},
#  10199051: {Timestamp('2020-02-01 00:00:00'): courier_id                            10199051
#   level                                        0
#   speed                                  4.39652
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                         0.75
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      334
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 73, dtype: object},
#  10731534: {Timestamp('2020-02-01 00:00:00'): courier_id                            10731534
#   level                                        0
#   speed                                  4.66496
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                      0.28125
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  252.281
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 252, dtype: object},
#  117022737: {Timestamp('2020-02-01 00:00:00'): courier_id                           117022737
#   level                                        3
#   speed                                  4.49152
#   max_load                                    12
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 413, dtype: object},
#  113147922: {Timestamp('2020-02-01 00:00:00'): courier_id                           113147922
#   level                                        3
#   speed                                  4.45892
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                        0.125
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  236.125
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 120, dtype: object},
#  118448145: {Timestamp('2020-02-01 00:00:00'): courier_id                           118448145
#   level                                        2
#   speed                                  4.73732
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.823529
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  286.353
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          14
#   Name: 592, dtype: object},
#  122081305: {Timestamp('2020-02-01 00:00:00'): courier_id                           122081305
#   level                                        3
#   speed                                  4.75507
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                          0.4
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                       98
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 199, dtype: object},
#  124612641: {Timestamp('2020-02-01 00:00:00'): courier_id                           124612641
#   level                                        1
#   speed                                  4.53005
#   max_load                                     7
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                          0.5
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      104
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 65, dtype: object},
#  117065769: {Timestamp('2020-02-01 00:00:00'): courier_id                           117065769
#   level                                        2
#   speed                                  4.34265
#   max_load                                     5
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                         0.75
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  140.417
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          27
#   Name: 371, dtype: object},
#  118802473: {Timestamp('2020-02-01 00:00:00'): courier_id                           118802473
#   level                                        3
#   speed                                  4.51468
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.333333
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                       74
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          15
#   Name: 566, dtype: object},
#  10627115: {Timestamp('2020-02-01 00:00:00'): courier_id                            10627115
#   level                                        3
#   speed                                  4.70748
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                        0.875
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  812.938
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          42
#   Name: 560, dtype: object},
#  10659886: {Timestamp('2020-02-01 00:00:00'): courier_id                            10659886
#   level                                        3
#   speed                                  4.64707
#   max_load                                     7
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                          0.4
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                    255.4
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 349, dtype: object},
#  10756147: {Timestamp('2020-02-01 00:00:00'): courier_id                            10756147
#   level                                        3
#   speed                                  4.59026
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 647, dtype: object},
#  119666745: {Timestamp('2020-02-01 00:00:00'): courier_id                           119666745
#   level                                        2
#   speed                                  4.65945
#   max_load                                     6
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                         0.82
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                   480.64
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          41
#   Name: 309, dtype: object},
#  102895674: {Timestamp('2020-02-01 00:00:00'): courier_id                           102895674
#   level                                        3
#   speed                                   4.4899
#   max_load                                    12
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                       22
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           5
#   Name: 506, dtype: object},
#  118917177: {Timestamp('2020-02-01 00:00:00'): courier_id                           118917177
#   level                                        2
#   speed                                  4.43005
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.368421
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  56.3684
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           7
#   Name: 600, dtype: object},
#  122060865: {Timestamp('2020-02-01 00:00:00'): courier_id                           122060865
#   level                                        3
#   speed                                  4.49551
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.130435
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  64.3043
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 248, dtype: object},
#  117164105: {Timestamp('2020-02-01 00:00:00'): courier_id                           117164105
#   level                                        2
#   speed                                  4.58212
#   max_load                                     7
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.333333
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      156
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 251, dtype: object},
#  10219599: {Timestamp('2020-02-01 00:00:00'): courier_id                            10219599
#   level                                        3
#   speed                                  4.44746
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      305
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 59, dtype: object},
#  10676303: {Timestamp('2020-02-01 00:00:00'): courier_id                            10676303
#   level                                        3
#   speed                                  4.67487
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 187, dtype: object},
#  117428305: {Timestamp('2020-02-01 00:00:00'): courier_id                           117428305
#   level                                        2
#   speed                                   4.4543
#   max_load                                     5
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                          0.5
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      142
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 121, dtype: object},
#  10164305: {Timestamp('2020-02-01 00:00:00'): courier_id                            10164305
#   level                                        1
#   speed                                  4.41507
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 184, dtype: object},
#  118347857: {Timestamp('2020-02-01 00:00:00'): courier_id                           118347857
#   level                                        3
#   speed                                  4.69461
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 556, dtype: object},
#  10094682: {Timestamp('2020-02-01 00:00:00'): courier_id                            10094682
#   level                                        3
#   speed                                  4.52236
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 396, dtype: object},
#  125155433: {Timestamp('2020-02-01 00:00:00'): courier_id                           125155433
#   level                                        3
#   speed                                  4.64323
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 33, dtype: object},
#  102697066: {Timestamp('2020-02-01 00:00:00'): courier_id                           102697066
#   level                                        3
#   speed                                  4.46372
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.714286
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  906.643
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          20
#   Name: 0, dtype: object},
#  110997610: {Timestamp('2020-02-01 00:00:00'): courier_id                           110997610
#   level                                        3
#   speed                                  4.35481
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 605, dtype: object},
#  103645298: {Timestamp('2020-02-01 00:00:00'): courier_id                           103645298
#   level                                        3
#   speed                                  4.37105
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.785714
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  1734.21
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          11
#   Name: 632, dtype: object},
#  125102201: {Timestamp('2020-02-01 00:00:00'): courier_id                           125102201
#   level                                        1
#   speed                                  4.76282
#   max_load                                     7
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                        0.625
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  705.625
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           5
#   Name: 404, dtype: object},
#  106582138: {Timestamp('2020-02-01 00:00:00'): courier_id                           106582138
#   level                                        2
#   speed                                  4.55168
#   max_load                                     6
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                          0.5
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                    206.5
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 565, dtype: object},
#  10815609: {Timestamp('2020-02-01 00:00:00'): courier_id                            10815609
#   level                                        3
#   speed                                  4.65023
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.541667
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  85.5833
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          13
#   Name: 659, dtype: object},
#  101009538: {Timestamp('2020-02-01 00:00:00'): courier_id                           101009538
#   level                                        3
#   speed                                  4.45557
#   max_load                                    12
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                    0.0555556
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  2.05556
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 215, dtype: object},
#  10784899: {Timestamp('2020-02-01 00:00:00'): courier_id                            10784899
#   level                                        3
#   speed                                  4.66935
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 376, dtype: object},
#  112597122: {Timestamp('2020-02-01 00:00:00'): courier_id                           112597122
#   level                                        2
#   speed                                  4.39452
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      652
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 445, dtype: object},
#  10760325: {Timestamp('2020-02-01 00:00:00'): courier_id                            10760325
#   level                                        2
#   speed                                  4.55311
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                          0.5
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                     51.6
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          20
#   Name: 322, dtype: object},
#  10793094: {Timestamp('2020-02-01 00:00:00'): courier_id                            10793094
#   level                                        3
#   speed                                  4.44139
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                    314.5
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 136, dtype: object},
#  10449032: {Timestamp('2020-02-01 00:00:00'): courier_id                            10449032
#   level                                        2
#   speed                                  5.62921
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 630, dtype: object},
#  120549513: {Timestamp('2020-02-01 00:00:00'): courier_id                           120549513
#   level                                        3
#   speed                                  4.43141
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 99, dtype: object},
#  118329481: {Timestamp('2020-02-01 00:00:00'): courier_id                           118329481
#   level                                        3
#   speed                                  4.69988
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.333333
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                   193.25
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          12
#   Name: 124, dtype: object},
#  117055625: {Timestamp('2020-02-01 00:00:00'): courier_id                           117055625
#   level                                        3
#   speed                                   4.4781
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.391304
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  949.696
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 382, dtype: object},
#  10711180: {Timestamp('2020-02-01 00:00:00'): courier_id                            10711180
#   level                                        2
#   speed                                  4.42409
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.470588
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  54.5882
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           8
#   Name: 109, dtype: object},
#  117108873: {Timestamp('2020-02-01 00:00:00'): courier_id                           117108873
#   level                                        3
#   speed                                  4.41605
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                         0.75
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                   13.125
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          18
#   Name: 414, dtype: object},
#  103135370: {Timestamp('2020-02-01 00:00:00'): courier_id                           103135370
#   level                                        3
#   speed                                  5.41508
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.193548
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  258.581
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 498, dtype: object},
#  124928145: {Timestamp('2020-02-01 00:00:00'): courier_id                           124928145
#   level                                        3
#   speed                                   4.6815
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 356, dtype: object},
#  122220689: {Timestamp('2020-02-01 00:00:00'): courier_id                           122220689
#   level                                        3
#   speed                                  4.41252
#   max_load                                    12
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      359
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 415, dtype: object},
#  10098837: {Timestamp('2020-02-01 00:00:00'): courier_id                            10098837
#   level                                        0
#   speed                                  4.52856
#   max_load                                    15
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.115385
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  93.6923
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 38, dtype: object},
#  10799255: {Timestamp('2020-02-01 00:00:00'): courier_id                            10799255
#   level                                        2
#   speed                                   4.3691
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 118, dtype: object},
#  103006362: {Timestamp('2020-02-01 00:00:00'): courier_id                           103006362
#   level                                        3
#   speed                                  4.78615
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.892857
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  576.714
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          25
#   Name: 299, dtype: object},
#  124981409: {Timestamp('2020-02-01 00:00:00'): courier_id                           124981409
#   level                                        2
#   speed                                  4.67248
#   max_load                                     5
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 233, dtype: object},
#  10643621: {Timestamp('2020-02-01 00:00:00'): courier_id                            10643621
#   level                                        2
#   speed                                  4.68228
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                    182.5
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 646, dtype: object},
#  115450025: {Timestamp('2020-02-01 00:00:00'): courier_id                           115450025
#   level                                        3
#   speed                                     4.77
#   max_load                                    13
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 296, dtype: object},
#  118818985: {Timestamp('2020-02-01 00:00:00'): courier_id                           118818985
#   level                                        3
#   speed                                  4.68133
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                        0.375
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                    145.5
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 27, dtype: object},
#  118266025: {Timestamp('2020-02-01 00:00:00'): courier_id                           118266025
#   level                                        3
#   speed                                  4.76083
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.833333
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  498.167
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          15
#   Name: 80, dtype: object},
#  118427817: {Timestamp('2020-02-01 00:00:00'): courier_id                           118427817
#   level                                        3
#   speed                                  4.67765
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                     1210
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 125, dtype: object},
#  10469547: {Timestamp('2020-02-01 00:00:00'): courier_id                            10469547
#   level                                        1
#   speed                                  4.78977
#   max_load                                     4
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.708333
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  380.667
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          17
#   Name: 222, dtype: object},
#  111743154: {Timestamp('2020-02-01 00:00:00'): courier_id                           111743154
#   level                                        2
#   speed                                  4.26056
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.409091
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  23.7273
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 54, dtype: object},
#  103502002: {Timestamp('2020-02-01 00:00:00'): courier_id                           103502002
#   level                                        3
#   speed                                  4.42123
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                       0.5625
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  342.562
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 196, dtype: object},
#  122775745: {Timestamp('2020-02-01 00:00:00'): courier_id                           122775745
#   level                                        2
#   speed                                  4.46918
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                        0.375
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  728.625
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 318, dtype: object},
#  10135747: {Timestamp('2020-02-01 00:00:00'): courier_id                            10135747
#   level                                        1
#   speed                                  4.67169
#   max_load                                     7
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 489, dtype: object},
#  106834122: {Timestamp('2020-02-01 00:00:00'): courier_id                           106834122
#   level                                        3
#   speed                                  4.51735
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.214286
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  2.57143
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 373, dtype: object},
#  113600721: {Timestamp('2020-02-01 00:00:00'): courier_id                           113600721
#   level                                        3
#   speed                                  4.59406
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.666667
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  122.667
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 507, dtype: object},
#  10272985: {Timestamp('2020-02-01 00:00:00'): courier_id                            10272985
#   level                                        3
#   speed                                  4.59761
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 42, dtype: object},
#  10711258: {Timestamp('2020-02-01 00:00:00'): courier_id                            10711258
#   level                                        3
#   speed                                  4.66154
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.454545
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  53.1818
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           5
#   Name: 161, dtype: object},
#  114634969: {Timestamp('2020-02-01 00:00:00'): courier_id                           114634969
#   level                                        3
#   speed                                  4.73177
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                    235.5
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 648, dtype: object},
#  122079457: {Timestamp('2020-02-01 00:00:00'): courier_id                           122079457
#   level                                        3
#   speed                                  4.72973
#   max_load                                     7
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.230769
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  153.923
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 153, dtype: object},
#  117049569: {Timestamp('2020-02-01 00:00:00'): courier_id                           117049569
#   level                                        3
#   speed                                  4.40387
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.409091
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  165.545
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 487, dtype: object},
#  115753185: {Timestamp('2020-02-01 00:00:00'): courier_id                           115753185
#   level                                        3
#   speed                                  4.79615
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.666667
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  175.333
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 635, dtype: object},
#  10258665: {Timestamp('2020-02-01 00:00:00'): courier_id                            10258665
#   level                                        3
#   speed                                  4.66418
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                     2398
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 347, dtype: object},
#  102246634: {Timestamp('2020-02-01 00:00:00'): courier_id                           102246634
#   level                                        2
#   speed                                  4.39591
#   max_load                                     7
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.857143
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  1064.71
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          18
#   Name: 185, dtype: object},
#  118593769: {Timestamp('2020-02-01 00:00:00'): courier_id                           118593769
#   level                                        3
#   speed                                  4.76454
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 399, dtype: object},
#  10703085: {Timestamp('2020-02-01 00:00:00'): courier_id                            10703085
#   level                                        3
#   speed                                  4.36919
#   max_load                                     7
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.333333
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      367
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 246, dtype: object},
#  121778417: {Timestamp('2020-02-01 00:00:00'): courier_id                           121778417
#   level                                        2
#   speed                                  4.74606
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      446
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 281, dtype: object},
#  102437106: {Timestamp('2020-02-01 00:00:00'): courier_id                           102437106
#   level                                        3
#   speed                                  4.41938
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  2023.67
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 357, dtype: object},
#  110944498: {Timestamp('2020-02-01 00:00:00'): courier_id                           110944498
#   level                                        3
#   speed                                  4.39426
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 460, dtype: object},
#  117672177: {Timestamp('2020-02-01 00:00:00'): courier_id                           117672177
#   level                                        2
#   speed                                  4.79892
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 501, dtype: object},
#  118810873: {Timestamp('2020-02-01 00:00:00'): courier_id                           118810873
#   level                                        3
#   speed                                  4.66504
#   max_load                                     4
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.428571
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  605.786
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 228, dtype: object},
#  112804090: {Timestamp('2020-02-01 00:00:00'): courier_id                           112804090
#   level                                        2
#   speed                                  4.37021
#   max_load                                    10
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      243
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 500, dtype: object},
#  118180113: {Timestamp('2020-02-01 00:00:00'): courier_id                           118180113
#   level                                        1
#   speed                                  4.69215
# ...
#   Name: 286, dtype: object},
#  119058345: {Timestamp('2020-02-01 00:00:00'): courier_id                           119058345
#   level                                        1
#   speed                                  4.51273
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.142857
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  52.1429
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 438, dtype: object},
#  110577578: {Timestamp('2020-02-01 00:00:00'): courier_id                           110577578
#   level                                        0
#   speed                                   4.7736
#   max_load                                     3
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                          0.5
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      267
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 250, dtype: object},
#  111751082: {Timestamp('2020-02-01 00:00:00'): courier_id                           111751082
#   level                                        3
#   speed                                   4.4916
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  523.667
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 344, dtype: object},
#  104673194: {Timestamp('2020-02-01 00:00:00'): courier_id                           104673194
#   level                                        2
#   speed                                  4.68721
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                          0.8
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                   2331.2
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          12
#   Name: 617, dtype: object},
#  125157297: {Timestamp('2020-02-01 00:00:00'): courier_id                           125157297
#   level                                        3
#   speed                                  4.69333
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                          0.8
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                    549.4
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          12
#   Name: 478, dtype: object},
#  103040946: {Timestamp('2020-02-01 00:00:00'): courier_id                           103040946
#   level                                        2
#   speed                                  4.73246
#   max_load                                     6
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.666667
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      154
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           6
#   Name: 518, dtype: object},
#  115365817: {Timestamp('2020-02-01 00:00:00'): courier_id                           115365817
#   level                                        3
#   speed                                  4.41906
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                         0.75
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                   323.25
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 306, dtype: object},
#  10393533: {Timestamp('2020-02-01 00:00:00'): courier_id                            10393533
#   level                                        3
#   speed                                  4.48363
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.432432
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  108.027
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          16
#   Name: 490, dtype: object},
#  101437378: {Timestamp('2020-02-01 00:00:00'): courier_id                           101437378
#   level                                        3
#   speed                                  4.77505
#   max_load                                     7
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.428571
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  152.429
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 291, dtype: object},
#  10303432: {Timestamp('2020-02-01 00:00:00'): courier_id                            10303432
#   level                                        2
#   speed                                  4.70615
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.869565
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                   1933.7
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          20
#   Name: 563, dtype: object},
#  112607178: {Timestamp('2020-02-01 00:00:00'): courier_id                           112607178
#   level                                        2
#   speed                                  4.60355
#   max_load                                     7
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 293, dtype: object},
#  10303438: {Timestamp('2020-02-01 00:00:00'): courier_id                            10303438
#   level                                        3
#   speed                                  4.37174
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.138889
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  4013.19
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           5
#   Name: 122, dtype: object},
#  118448081: {Timestamp('2020-02-01 00:00:00'): courier_id                           118448081
#   level                                        2
#   speed                                  4.45803
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.230769
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                       30
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 596, dtype: object},
#  10102738: {Timestamp('2020-02-01 00:00:00'): courier_id                            10102738
#   level                                        3
#   speed                                  4.43671
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.130435
#   delivery_delay_rate                   0.230769
#   pickup_delay_time_avg                  12.7826
#   delivery_delay_time_avg                     63
#   delivery_delay_count                         6
#   pickup_delay_count                           3
#   Name: 148, dtype: object},
#  113977305: {Timestamp('2020-02-01 00:00:00'): courier_id                           113977305
#   level                                        3
#   speed                                  4.73533
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                         0.25
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                    51.25
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 265, dtype: object},
#  106973146: {Timestamp('2020-02-01 00:00:00'): courier_id                           106973146
#   level                                        2
#   speed                                   4.7204
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                          0.5
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                      249
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 152, dtype: object},
#  118804441: {Timestamp('2020-02-01 00:00:00'): courier_id                           118804441
#   level                                        3
#   speed                                  4.74656
#   max_load                                    11
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                     1050
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 303, dtype: object},
#  118970329: {Timestamp('2020-02-01 00:00:00'): courier_id                           118970329
#   level                                        3
#   speed                                  4.78013
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                    0.0857143
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  51.9429
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 618, dtype: object},
#  122161113: {Timestamp('2020-02-01 00:00:00'): courier_id                           122161113
#   level                                        3
#   speed                                  4.44989
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 636, dtype: object},
#  116971497: {Timestamp('2020-02-01 00:00:00'): courier_id                           116971497
#   level                                        3
#   speed                                   4.5875
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.454545
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  531.182
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                          15
#   Name: 40, dtype: object},
#  122154985: {Timestamp('2020-02-01 00:00:00'): courier_id                           122154985
#   level                                        3
#   speed                                   4.5806
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                          0.5
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  15774.5
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           3
#   Name: 317, dtype: object},
#  10037225: {Timestamp('2020-02-01 00:00:00'): courier_id                            10037225
#   level                                        1
#   speed                                  4.39002
#   max_load                                     7
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            0
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                        0
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           0
#   Name: 601, dtype: object},
#  122077169: {Timestamp('2020-02-01 00:00:00'): courier_id                           122077169
#   level                                        2
#   speed                                  4.59965
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.454545
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  37.2727
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           5
#   Name: 130, dtype: object},
#  116191217: {Timestamp('2020-02-01 00:00:00'): courier_id                           116191217
#   level                                        3
#   speed                                  4.57447
#   max_load                                     9
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                         0.36
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                   177.84
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           9
#   Name: 430, dtype: object},
#  118310905: {Timestamp('2020-02-01 00:00:00'): courier_id                           118310905
#   level                                        3
#   speed                                   4.6688
#   max_load                                    12
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                     0.192308
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                  381.538
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           5
#   Name: 339, dtype: object},
#  101992442: {Timestamp('2020-02-01 00:00:00'): courier_id                           101992442
#   level                                        1
#   speed                                  4.14915
#   max_load                                     8
#   date                       2020-02-01 00:00:00
#   pickup_delay_rate                            1
#   delivery_delay_rate                          0
#   pickup_delay_time_avg                     1557
#   delivery_delay_time_avg                      0
#   delivery_delay_count                         0
#   pickup_delay_count                           7
#   Name: 292, dtype: object}}

# %% [markdown]
# # 保存数据

# %%
pickle_path = './2_generate_train_test_courier_feature/mp_couriers_features_train.pickle'
with open(pickle_path, 'wb') as f:
    pickle.dump(mp_couriers_features_train, f)

pickle_path = './2_generate_train_test_courier_feature/mp_couriers_features_testA.pickle'
with open(pickle_path, 'wb') as f:
    pickle.dump(mp_couriers_features_testA, f)
